# %%
import pandas as pd
import numpy as np

from keras.preprocessing.text import *
from keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import CuDNNLSTM
from keras.layers.embeddings import Embedding
from keras.metrics import categorical_accuracy

# %%
data = pd.read_csv('dataset/preProcessSentiment.csv', index_col=0)
data = data[['text', 'FOOD', 'PRICE', 'SERVICE', 'AMBIENCE']]

def convert(elem):
    elem[0] = "FOOD_" + elem[0]
    elem[1] = "PRICE_" + elem[1]
    elem[2] = "SERVICE_" + elem[2]
    elem[3] = "AMBIENCE_" + elem[3]
    return elem

corpus = data.values[:,0]
label = list(map(convert,data.values[:,1:].tolist()))
label
# Out:
# [['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
# ...
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_NEGATIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_NEGATIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_NEGATIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_NEGATIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_UNKNOWN', 'PRICE_POSITIVE', 'SERVICE_NEGATIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_UNKNOWN'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ['FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE', 'AMBIENCE_POSITIVE'],
#  ...]

# %%
encoder  = MultiLabelBinarizer()
labels = encoder.fit_transform(label)

# %%
test = pd.read_csv('dataset/gold_sentiment.csv', index_col=0)
test = test[['text', 'FOOD', 'PRICE', 'SERVICE', 'AMBIENCE']]

test_label = list(map(convert,test.values[:,1:].tolist()))
test_corpus = test.values[:,0]

test_label = encoder.transform(test_label)

# %%
vocab_size = 20000
max_length = 150
encoded_docs = [one_hot(d, vocab_size) for d in corpus]
padded_docs = pad_sequences(encoded_docs, maxlen=max_length, padding='post')

encoded_test = [one_hot(d, vocab_size) for d in test_corpus]
padded_test = pad_sequences(encoded_test, maxlen=max_length, padding='post')

# %%
model = Sequential()
model.add(Embedding(vocab_size, 512, input_length=max_length))
model.add(CuDNNLSTM(128))
model.add(Dense(12, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc', categorical_accuracy])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, 150, 512)          10240000
# _________________________________________________________________
# cu_dnnlstm_4 (CuDNNLSTM)     (None, 128)               328704
# _________________________________________________________________
# dense_10 (Dense)             (None, 12)                1548
# =================================================================
# Total params: 10,570,252
# Trainable params: 10,570,252
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.fit(padded_docs, np.array(labels), epochs=15)
# Out:
# Epoch 1/15
# 3865/3865 [==============================] - 6s 2ms/step - loss: 0.4946 - acc: 0.7705 - categorical_accuracy: 5.1746e-04
# Epoch 2/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4839 - acc: 0.7733 - categorical_accuracy: 0.0000e+00
# Epoch 3/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4805 - acc: 0.7754 - categorical_accuracy: 0.0013
# Epoch 4/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4773 - acc: 0.7793 - categorical_accuracy: 0.0000e+00
# Epoch 5/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4721 - acc: 0.7821 - categorical_accuracy: 0.0031
# Epoch 6/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4681 - acc: 0.7855 - categorical_accuracy: 0.0057
# Epoch 7/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4697 - acc: 0.7842 - categorical_accuracy: 0.0016
# Epoch 8/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4597 - acc: 0.7906 - categorical_accuracy: 0.0041
# Epoch 9/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4596 - acc: 0.7908 - categorical_accuracy: 0.0049
# Epoch 10/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4339 - acc: 0.8102 - categorical_accuracy: 0.0129
# Epoch 11/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.4059 - acc: 0.8301 - categorical_accuracy: 0.0114
# Epoch 12/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.3709 - acc: 0.8524 - categorical_accuracy: 0.0502
# Epoch 13/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.3117 - acc: 0.8815 - categorical_accuracy: 0.1105
# Epoch 14/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.2583 - acc: 0.9042 - categorical_accuracy: 0.1400
# Epoch 15/15
# 3865/3865 [==============================] - 4s 1ms/step - loss: 0.2122 - acc: 0.9219 - categorical_accuracy: 0.1151

# %%
model.evaluate(padded_test, np.array(test_label))
# Out:
# 150/150 [==============================] - 0s 3ms/step
# [0.5276323922475179, 0.7727777711550394, 0.06]

# %%
result = model.predict(padded_test)
result
# Out:
# array([[0.07373809, 0.67728895, 0.14945637, ..., 0.03831172, 0.01302223,
#         0.95357513],
#        [0.2307323 , 0.10283428, 0.6246008 , ..., 0.05008041, 0.00980868,
#         0.985068  ],
#        [0.16644225, 0.12394237, 0.7075251 , ..., 0.40931708, 0.74638486,
#         0.01592148],
#        ...,
#        [0.04349829, 0.9497142 , 0.03308911, ..., 0.07488237, 0.9564393 ,
#         0.0051264 ],
#        [0.11160324, 0.38139918, 0.5535289 , ..., 0.3862949 , 0.90450525,
#         0.00458602],
#        [0.00577857, 0.06332741, 0.9666051 , ..., 0.05448318, 0.46222126,
#         0.17723331]], dtype=float32)

# %%
normalize = lambda x: 1 if x >= 0.5 else 0
normalize_arr = lambda arr : [normalize(elem) for elem in arr]
result_normal = np.array(list(map(normalize_arr, result)))
result_normal = encoder.inverse_transform(result_normal)

# %%
result_normal
# Out:
# [('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_NEGATIVE'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE',
#   'FOOD_POSITIVE',
#   'PRICE_UNKNOWN',
#   'SERVICE_NEGATIVE',
#   'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('FOOD_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_NEGATIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE'),
#  ('AMBIENCE_POSITIVE',
#   'AMBIENCE_UNKNOWN',
#   'FOOD_POSITIVE',
#   'PRICE_POSITIVE',
#   'SERVICE_POSITIVE'),
#  ('FOOD_POSITIVE', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE',
#   'FOOD_POSITIVE',
#   'PRICE_NEGATIVE',
#   'PRICE_UNKNOWN',
#   'SERVICE_POSITIVE'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN',
#   'FOOD_POSITIVE',
#   'PRICE_UNKNOWN',
#   'SERVICE_NEGATIVE',
#   'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN',
#   'FOOD_POSITIVE',
#   'PRICE_UNKNOWN',
#   'SERVICE_NEGATIVE',
#   'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_POSITIVE'),
#  ('FOOD_POSITIVE', 'SERVICE_NEGATIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'SERVICE_UNKNOWN'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_NEGATIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE',
#   'PRICE_UNKNOWN',
#   'SERVICE_NEGATIVE',
#   'SERVICE_POSITIVE'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_UNKNOWN'),
#  ('AMBIENCE_POSITIVE', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN', 'SERVICE_POSITIVE'),
#  ('AMBIENCE_UNKNOWN', 'FOOD_POSITIVE', 'PRICE_UNKNOWN')]
